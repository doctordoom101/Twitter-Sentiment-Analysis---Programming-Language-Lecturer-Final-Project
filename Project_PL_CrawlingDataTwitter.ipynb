# %% [markdown]
# <a href="https://colab.research.google.com/github/doctordoom101/Twitter-Sentiment-Analysis---Programming-Language-Lecturer-Final-Project/blob/main/Project_PL_CrawlingDataTwitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crawl Data Twitter June 12, 2024
# ### The crawling process was done using Tweet-Harvest.

# %%
#@title Twitter auth token
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,173 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,525 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,900 kB]
# ...

# %% [markdown]
# ## Data Crawling (Testing)

# %%
# Crawl Data 1

filename = 'data_tweet_mhr.draf1.csv'
search_keyword = 'mental health remaja lang:id'
limit = 6000
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Filling in keywords: mental health remaja lang:id
#
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.csv
# Total tweets saved: 15
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.csv
# Total tweets saved: 34
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.csv
# Total tweets saved: 51
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.csv
# Total tweets saved: 70
#
# -- Scrolling... (1)
#
# ...

# %%
# Crawl Data 2

filename = 'data_tweet_mhr.draf2.csv'
search_keyword = 'mental health remaja until:2024-06-12 since:2020-03-01'
limit = 6000
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: mental health remaja until:2024-06-12 since:2020-03-01
#
#  (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf2.csv
# Total tweets saved: 15
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf2.csv
# Total tweets saved: 33
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf2.csv
# Total tweets saved: 50
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf2.csv
# Total tweets saved: 69
#
# ...

# %%
# Crawl Data 3

filename = 'data_tweet_mhr.draf3.csv'
search_keyword = 'mental health remaja until:2024-06-12 since:2020-03-01'
limit = 6000
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: mental health remaja until:2024-06-12 since:2020-03-01
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf3.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf3.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf3.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf3.csv
# Total tweets saved: 80
#
# ...

# %%
# Crawl Data 7

filename = 'kesehatan_mental_remaja.csv'
search_keyword = 'kesehatan mental remaja lang:id'
limit = 6000
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: kesehatan mental remaja lang:id
#
#  (3)
#
# Your tweets saved to: /content/tweets-data/kesehatan_mental_remaja.csv
# Total tweets saved: 11
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/kesehatan_mental_remaja.csv
# Total tweets saved: 23
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/kesehatan_mental_remaja.csv
# Total tweets saved: 35
#
# ...

# %% [markdown]
# # Data Crawling
# ### string keywords : 'teenage mental health' , 'teens mental health' , 'teen mental health'
# *Done on June 13, 2024*

# %%
## Crawl Data 4

filename = 'teenage.csv'
search_keyword = 'teenage mental health'
limit = 6000
twitter_auth_token = 'ksbfiusbvierubriub'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠦⠧npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠧npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/teenage.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)

# Check the length of the DataFrame
num_rows = len(df)
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1800576294473666667  Tue Jun 11 17:10:16 +0000 2024               0
# 1     1800573991423189121  Tue Jun 11 17:01:07 +0000 2024               0
# 2     1800573990408180161  Tue Jun 11 17:01:07 +0000 2024               0
# 3     1800558605189406972  Tue Jun 11 15:59:58 +0000 2024               1
# 4     1800558603851514124  Tue Jun 11 15:59:58 +0000 2024               0
# ...                   ...                             ...             ...
# 2459  1666083318457323523  Tue Jun 06 14:03:12 +0000 2023               0
# 2460  1666083262689861639  Tue Jun 06 14:02:58 +0000 2023               0
# 2461  1666057787028152321  Tue Jun 06 12:21:44 +0000 2023              11
# 2462  1665813316223086592  Tue Jun 06 12:04:51 +0000 2023               0
# 2463  1666041959238991873  Tue Jun 06 11:18:52 +0000 2023               0
#
#                                               full_text               id_str  \
# ...

# %%
## Crawl Data 5

filename = 'teens.csv'
search_keyword = 'teens mental health'
limit = 6000
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/data_tweet_mhr.draf4.csv, renaming to ./tweets-data/data_tweet_mhr.draf4.old.csv
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: teens mental health
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf4.csv
# Total tweets saved: 19
#
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf4.csv
# Total tweets saved: 36
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf4.csv
# Total tweets saved: 54
#
# -- Scrolling... (1) (2)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/teens.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)

# Check the length of the DataFrame
num_rows = len(df)
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1801071300611334458  Thu Jun 13 03:09:19 +0000 2024               0
# 1    1801027816491823160  Thu Jun 13 01:03:07 +0000 2024               1
# 2    1801051044710875230  Thu Jun 13 00:36:45 +0000 2024               0
# 3    1801035719592616221  Wed Jun 12 23:35:51 +0000 2024               1
# 4    1801021714018574514  Wed Jun 12 22:40:12 +0000 2024               0
# ..                   ...                             ...             ...
# 988  1790530111101424061  Tue May 14 23:50:19 +0000 2024               1
# 989  1790517450465042942  Tue May 14 23:00:01 +0000 2024               1
# 990  1790506711033286986  Tue May 14 22:33:52 +0000 2024               1
# 991  1790510270189862966  Tue May 14 22:31:29 +0000 2024               1
# 992  1790509897878061151  Tue May 14 22:30:00 +0000 2024               0
#
#                                              full_text               id_str  \
# ...

# %%
# Crawl Data 6

filename = 'teen.csv'
search_keyword = 'teen mental health'
limit = 6000
twitter_auth_token = 'cb8d664d5d6164dc0019a969c439fb0bf3ce201b'

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: teen mental health
#
#  (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf6.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf6.csv
# Total tweets saved: 37
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf6.csv
# Total tweets saved: 55
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_tweet_mhr.draf6.csv
# Total tweets saved: 73
#
# -- Scrolling... (1)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/teen.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)

# Check the length of the DataFrame
num_rows = len(df)
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1800928558014968176  Wed Jun 12 16:30:02 +0000 2024               0
# 1     1800915917897187690  Wed Jun 12 15:39:48 +0000 2024               0
# 2     1800911128933085525  Wed Jun 12 15:25:06 +0000 2024               6
# 3     1800911988652118099  Wed Jun 12 15:24:12 +0000 2024               1
# 4     1800911945018565060  Wed Jun 12 15:24:01 +0000 2024              16
# ...                   ...                             ...             ...
# 2748  1763955234685018320  Sat Mar 02 15:51:15 +0000 2024               9
# 2749  1763954919730786797  Sat Mar 02 15:50:00 +0000 2024               0
# 2750  1763912283929931939  Sat Mar 02 13:00:35 +0000 2024               0
# 2751  1763912147355218089  Sat Mar 02 13:00:02 +0000 2024               3
# 2752  1763912138127757792  Sat Mar 02 13:00:00 +0000 2024               0
#
#                                               full_text               id_str  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Merging Datasets

# %%
import pandas as pd

# %%
#@title dataset 1 "teenage"

url1 = "/content/drive/MyDrive/Datasets_projectPL/teenage.csv"
df1 = pd.read_csv(url1)
df1.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1800576294473666667  Tue Jun 11 17:10:16 +0000 2024               0
# 1  1800573991423189121  Tue Jun 11 17:01:07 +0000 2024               0
# 2  1800573990408180161  Tue Jun 11 17:01:07 +0000 2024               0
# 3  1800558605189406972  Tue Jun 11 15:59:58 +0000 2024               1
# 4  1800558603851514124  Tue Jun 11 15:59:58 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  Meet Dr. Perry Adler a clinical psychologist l...  1800576294473666667
# 1  As many parents know our teenage years while m...  1800573991423189121
# 2  As many parents know our teenage years while m...  1800573990408180161
# 3  As many parents know our teenage years while m...  1800558605189406972
# 4  As many parents know our teenage years while m...  1800558603851514124
#
#   image_url in_reply_to_screen_name lang                 location  \
# ...

# %%
#@title dataset 2 "teens"

url2 = "/content/drive/MyDrive/Datasets_projectPL/teens.csv"
df2 = pd.read_csv(url2)
df2.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1801071300611334458  Thu Jun 13 03:09:19 +0000 2024               0
# 1  1801027816491823160  Thu Jun 13 01:03:07 +0000 2024               1
# 2  1801051044710875230  Thu Jun 13 00:36:45 +0000 2024               0
# 3  1801035719592616221  Wed Jun 12 23:35:51 +0000 2024               1
# 4  1801021714018574514  Wed Jun 12 22:40:12 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  @BeachcatTt We pray for our children. But righ...  1801089438971535390
# 1  @tobycmurray @ACUmedia 100% agree. Despite thi...  1801057679634550959
# 2  Yesterday at the YHELP! Scholars program- CH w...  1801051044710875230
# 3  Washington launches mental health school safet...  1801035719592616221
# 4  Many things can influence your self-esteem inc...  1801021714018574514
#
#                                          image_url in_reply_to_screen_name  \
# ...

# %%
#@title dataset 3 "teen"

url3 = "/content/drive/MyDrive/Datasets_projectPL/teen.csv"
df3 = pd.read_csv(url3)
df3.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1800928558014968176  Wed Jun 12 16:30:02 +0000 2024               0
# 1  1800915917897187690  Wed Jun 12 15:39:48 +0000 2024               0
# 2  1800911128933085525  Wed Jun 12 15:25:06 +0000 2024               6
# 3  1800911988652118099  Wed Jun 12 15:24:12 +0000 2024               1
# 4  1800911945018565060  Wed Jun 12 15:24:01 +0000 2024              16
#
#                                            full_text               id_str  \
# 0   Download a list of Mental Health Hotlines and...  1800928558014968176
# 1  If Republicans were smart they would immediate...  1800915917897187690
# 2  insecurities. there are several diagnoses that...  1800912216339959839
# 3  Ummyeahhh.. I'm pretty sure THC has nothing to...  1800911988652118099
# 4  ESPN's Malika Andrews Shares Secret Teen Traum...  1800911945018565060
#
#                                          image_url in_reply_to_screen_name  \
# ...

# %% [markdown]
# ## merge 3 datasets

# %%
merge_dataset = pd.concat([df1, df2, df3], ignore_index=True)
merge_dataset.shape
# Out:
# (6210, 15)

# %%
merge_dataset
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1800576294473666667  Tue Jun 11 17:10:16 +0000 2024               0
# 1     1800573991423189121  Tue Jun 11 17:01:07 +0000 2024               0
# 2     1800573990408180161  Tue Jun 11 17:01:07 +0000 2024               0
# 3     1800558605189406972  Tue Jun 11 15:59:58 +0000 2024               1
# 4     1800558603851514124  Tue Jun 11 15:59:58 +0000 2024               0
# ...                   ...                             ...             ...
# 6205  1763955234685018320  Sat Mar 02 15:51:15 +0000 2024               9
# 6206  1763954919730786797  Sat Mar 02 15:50:00 +0000 2024               0
# 6207  1763912283929931939  Sat Mar 02 13:00:35 +0000 2024               0
# 6208  1763912147355218089  Sat Mar 02 13:00:02 +0000 2024               3
# 6209  1763912138127757792  Sat Mar 02 13:00:00 +0000 2024               0
#
#                                               full_text               id_str  \
# ...

# %%
merge_dataset.to_csv('/content/drive/MyDrive/Datasets_projectPL/merged_dataset.csv', index=False)

# %%
! ls
# Out:
# drive  merged_dataset  sample_data  teenage.csv  teen.csv  teens.csv

# %%
! cat merged_dataset.csv
# Out:
# cat: merged_dataset.csv: No such file or directory
